# %%
import pandas as pd

# %%
import pandas as pd

def read_csv(file_path):
    df = pd.read_csv(file_path, delimiter=',')
    return df

def clean_csv(file_path, columns_to_drop, filter_column=None, filter_value=None):
    df = read_csv(file_path)
    if filter_column is not None and filter_value is not None:
        df = df[df[filter_column] == filter_value]
    df = df.drop(columns=columns_to_drop, axis=1)
    return df

df_region = clean_csv("datafiles/area/v_region_2023.csv", ['CHEFLIEU', 'TNCC', 'NCC', 'NCCENR'])
df_departement = clean_csv("datafiles/area/v_departement_2023.csv", ['CHEFLIEU', 'TNCC', 'NCC', 'NCCENR'])
df_communes = clean_csv("datafiles/area/v_commune_2023.csv", 
                                 ['TYPECOM', 'REG', 'CTCD', 'ARR', 'TNCC', 'NCC', 'NCCENR', 'CAN', 'COMPARENT'], 
                                 filter_column='TYPECOM', filter_value='COM')
df_cheflieudep = clean_csv("datafiles/area/v_departement_2023.csv", ['REG', 'TNCC', 'NCC', 'NCCENR', 'LIBELLE'])
df_cheflieureg = clean_csv("datafiles/area/v_region_2023.csv", ['TNCC', 'NCC', 'NCCENR', 'LIBELLE'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 14
#      11     df = df.drop(columns=columns_to_drop, axis=1)
#      12     return df
# ---> 14 df_region = clean_csv("data/datafiles/area/v_region_2023.csv", ['CHEFLIEU', 'TNCC', 'NCC', 'NCCENR'])
#      15 df_departement = clean_csv("data/datafiles/area/v_departement_2023.csv", ['CHEFLIEU', 'TNCC', 'NCC', 'NCCENR'])
#      16 df_communes = clean_csv("data/datafiles/area/v_commune_2023.csv",
#      17                                  ['TYPECOM', 'REG', 'CTCD', 'ARR', 'TNCC', 'NCC', 'NCCENR', 'CAN', 'COMPARENT'],
#      18                                  filter_column='TYPECOM', filter_value='COM')
#
# Cell In[2], line 8, in clean_csv(file_path, columns_to_drop, filter_column, filter_value)
#       7 def clean_csv(file_path, columns_to_drop, filter_column=None, filter_value=None):
# ...

# %%
df = pd.read_csv("datafiles/population/France_hors_Mayotte.CSV", delimiter=';')
df.dropna(inplace=True)
df
# Out:
# /var/folders/h9/gdq2_8dx0470sq59hdb_jm480000gn/T/ipykernel_15246/3451836918.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("datafiles/population/France_hors_Mayotte.CSV", delimiter=';')
#       CODGEO  P20_POP  P14_POP  P09_POP  D99_POP  D90_POP  D82_POP  D75_POP  \
# 0       1001      806      767      787      728      579      477      368
# 1       1002      262      239      207      168      159      136      106
# 2       1004    14288    14022    13350    11436    10455     9737     9550
# 3       1005     1782     1627     1592     1408     1156      848      756
# 4       1006      113      109      120       86       76       65       82
# ...      ...      ...      ...      ...      ...      ...      ...      ...
# 34968  97420    24086    22406    22437    18144    14695    13196    11984
# 34969  97421     7310     7132     7406     7402     7004     6467     6462
# ...

# %%
# Supposons que votre DataFrame s'appelle df
types_de_donnees = df.dtypes

print(types_de_donnees)
# Out:
# CODGEO          object
# P20_POP          int64
# P14_POP          int64
# P09_POP          int64
# D99_POP          int64
#                 ...
# D99_PMEN         int64
# D90_NPER_RP      int64
# D82_NPER_RP    float64
# D75_NPER_RP    float64
# D68_NPER_RP    float64
# Length: 64, dtype: object
